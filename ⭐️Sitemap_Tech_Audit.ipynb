# %% [markdown]
# <a href="https://colab.research.google.com/github/simodepth/sitemap/blob/main/%E2%AD%90%EF%B8%8FSitemap_Tech_Audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Automate Sitemap Audit with Python
#
# XML sitemaps are designed to make life easier for search engines by providing an index of a site’s URLs. However, they’re also a useful tool in competitor analysis and allow you to quickly identify all of a site’s pages and the level of importance the site assigns to each page.
#
# The following Python script may help you cut off plenty of time of manual technical research and to fetch plenty of juicy data insights at the same time.

# %% [markdown]
# #Requirements and Assumptions
#
# - Run the script on **Google Colab**
# - Make sure to `!pip install` advertools and pandas packages
# - Remember that **[sitemaps are a recommendation](https://developers.google.com/search/docs/advanced/sitemaps/build-sitemap)** to Google about which pages you think are important; Google does not pledge to crawl every URL in a sitemap.

# %%
#@title Install Packages

# !pip install advertools
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting advertools
#   Downloading advertools-0.13.1-py2.py3-none-any.whl (309 kB)
#      |████████████████████████████████| 309 kB 5.2 MB/s
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from advertools) (6.0.1)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.7/dist-packages (from advertools) (0.4.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from advertools) (1.3.5)
# Collecting scrapy
#   Downloading Scrapy-2.6.1-py2.py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 65.8 MB/s
# Collecting twython
#   Downloading twython-3.9.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->advertools) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->advertools) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->advertools) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->advertools) (1.15.0)
# Collecting itemadapter>=0.1.0
#   Downloading itemadapter-0.6.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from scrapy->advertools) (4.2.6)
# Collecting PyDispatcher>=2.0.5
#   Downloading PyDispatcher-2.0.5.zip (47 kB)
#      |████████████████████████████████| 47 kB 6.5 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from scrapy->advertools) (57.4.0)
# Collecting queuelib>=1.4.2
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting zope.interface>=4.1.3
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 56.6 MB/s
# Collecting w3lib>=1.17.0
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting tldextract
#   Downloading tldextract-3.3.1-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.6 MB/s
# Collecting cssselect>=0.9.1
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting itemloaders>=1.0.1
#   Downloading itemloaders-1.0.4-py3-none-any.whl (11 kB)
# Collecting protego>=0.1.15
#   Downloading Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting pyOpenSSL>=16.2.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.6 MB/s
# Collecting cryptography>=2.0
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 57.7 MB/s
# Collecting service-identity>=16.0.0
#   Downloading service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Collecting Twisted>=17.9.0
#   Downloading Twisted-22.4.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 37.2 MB/s
# Collecting parsel>=1.5.0
#   Downloading parsel-1.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->scrapy->advertools) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->scrapy->advertools) (2.21)
# Collecting jmespath>=0.9.5
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.7/dist-packages (from service-identity>=16.0.0->scrapy->advertools) (21.4.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.7/dist-packages (from service-identity>=16.0.0->scrapy->advertools) (0.2.8)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from Twisted>=17.9.0->scrapy->advertools) (4.1.1)
# Collecting Automat>=0.8.0
#   Downloading Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Collecting hyperlink>=17.1.1
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 4.1 MB/s
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting incremental>=21.3.0
#   Downloading incremental-21.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.7/dist-packages (from hyperlink>=17.1.1->Twisted>=17.9.0->scrapy->advertools) (2.10)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy->advertools) (3.7.1)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy->advertools) (2.23.0)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy->advertools) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy->advertools) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy->advertools) (2022.6.15)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from twython->advertools) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.4.0->twython->advertools) (3.2.0)
# Building wheels for collected packages: PyDispatcher
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11516 sha256=d0343aa6e2204de5643751e64631c678dd973674f0fe8227030711d228d9c617
#   Stored in directory: /root/.cache/pip/wheels/2d/18/21/3c6a732eaa69a339198e08bb63b7da2c45933a3428b29ec454
# Successfully built PyDispatcher
# Installing collected packages: w3lib, cssselect, zope.interface, requests-file, parsel, jmespath, itemadapter, incremental, hyperlink, cryptography, constantly, Automat, Twisted, tldextract, service-identity, queuelib, pyOpenSSL, PyDispatcher, protego, itemloaders, twython, scrapy, advertools
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 Twisted-22.4.0 advertools-0.13.1 constantly-15.1.0 cryptography-37.0.4 cssselect-1.1.0 hyperlink-21.0.0 incremental-21.3.0 itemadapter-0.6.0 itemloaders-1.0.4 jmespath-1.0.1 parsel-1.6.0 protego-0.2.1 pyOpenSSL-22.0.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.6.1 service-identity-21.1.0 tldextract-3.3.1 twython-3.9.1 w3lib-1.22.0 zope.interface-5.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
#@title Import Packages
import advertools as adv

import pandas as pd

import requests

import time

import warnings
warnings.filterwarnings("ignore")

from lxml import etree

from IPython.core.display import display, HTML

from google.colab import files 

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#@title 1️⃣ Scrape URLs From The Sitemap
sitemap_url = "https://seodepths.com/sitemap_index.xml"
sitemap = adv.sitemap_to_df(sitemap_url)
sitemap.to_csv("sitemap.csv")
sitemap_df = pd.read_csv("sitemap.csv", index_col=False)
sitemap_df.drop(columns=["Unnamed: 0"], inplace=True)
sitemap_df
# Out:
# 2022-07-17 13:43:55,126 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://seodepths.com/post-sitemap.xml
# 2022-07-17 13:43:55,131 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://seodepths.com/page-sitemap.xml
#                                                  loc  \
# 0                             https://seodepths.com/
# 1  https://seodepths.com/python-for-seo/entity-an...
# 2  https://seodepths.com/seo-news/how-nlp-nlu-can...
# 3  https://seodepths.com/python-for-seo/define-se...
# 4  https://seodepths.com/python-for-seo/how-to-ki...
# 5  https://seodepths.com/python-for-seo/sitemap-a...
# 6  https://seodepths.com/python-for-seo/detect-go...
# 7  https://seodepths.com/seo-news/google-pros-con...
# 8                             https://seodepths.com/
# 9                       https://seodepths.com/about/
#
#                      lastmod     image  \
# 0                        NaN       NaN
# 1  2022-07-16 16:47:33+00:00  \n\t\t\t
# 2  2022-07-16 16:12:36+00:00  \n\t\t\t
# 3  2022-07-16 16:06:01+00:00  \n\t\t\t
# 4  2022-07-15 07:49:16+00:00  \n\t\t\t
# 5  2022-07-15 07:40:27+00:00  \n\t\t\t
# 6  2022-07-13 09:39:20+00:00  \n\t\t\t
# 7  2022-07-12 16:49:21+00:00  \n\t\t\t
# 8                        NaN       NaN
# 9  2022-07-13 10:13:25+00:00       NaN
#
#                                            image_loc  \
# 0                                                NaN
# 1  https://seodepths.com/wp-content/uploads/2022/...
# 2  https://seodepths.com/wp-content/uploads/2022/...
# 3  https://seodepths.com/wp-content/uploads/2022/...
# 4  https://seodepths.com/wp-content/uploads/2022/...
# 5  https://seodepths.com/wp-content/uploads/2022/...
# 6  https://seodepths.com/wp-content/uploads/2022/...
# 7  https://seodepths.com/wp-content/uploads/2022/...
# 8                                                NaN
# 9                                                NaN
#
#                                   sitemap  sitemap_size_mb  \
# 0  https://seodepths.com/post-sitemap.xml         0.005334
# 1  https://seodepths.com/post-sitemap.xml         0.005334
# 2  https://seodepths.com/post-sitemap.xml         0.005334
# 3  https://seodepths.com/post-sitemap.xml         0.005334
# 4  https://seodepths.com/post-sitemap.xml         0.005334
# 5  https://seodepths.com/post-sitemap.xml         0.005334
# 6  https://seodepths.com/post-sitemap.xml         0.005334
# 7  https://seodepths.com/post-sitemap.xml         0.005334
# 8  https://seodepths.com/page-sitemap.xml         0.000737
# 9  https://seodepths.com/page-sitemap.xml         0.000737
#
#                       download_date
# 0  2022-07-17 13:43:55.164529+00:00
# 1  2022-07-17 13:43:55.164529+00:00
# 2  2022-07-17 13:43:55.164529+00:00
# 3  2022-07-17 13:43:55.164529+00:00
# 4  2022-07-17 13:43:55.164529+00:00
# 5  2022-07-17 13:43:55.164529+00:00
# 6  2022-07-17 13:43:55.164529+00:00
# 7  2022-07-17 13:43:55.164529+00:00
# 8  2022-07-17 13:43:55.158998+00:00
# 9  2022-07-17 13:43:55.158998+00:00

# %%
#@title 2️⃣ Check Tag Usage Within The Sitemap (If Existing)
def check_sitemap_tag_usage(sitemap):
     lastmod = sitemap["lastmod"].isna().value_counts()
     priority = sitemap["priority"].isna().value_counts()
     changefreq = sitemap["changefreq"].isna().value_counts()
     lastmod_perc = sitemap["lastmod"].isna().value_counts(normalize = True) * 100
     priority_perc = sitemap["priority"].isna().value_counts(normalize = True) * 100
     changefreq_perc = sitemap["changefreq"].isna().value_counts(normalize = True) * 100
     sitemap_tag_usage_df = pd.DataFrame(data={"lastmod":lastmod,
     "priority":priority,
     "changefreq":changefreq,
     "lastmod_perc": lastmod_perc,
     "priority_perc": priority_perc,
     "changefreq_perc": changefreq_perc})
     return sitemap_tag_usage_df.astype(int)

# %% [markdown]
# # 📓 Sidenote
# - ✅ You want to make sure you have got `<loc>` and `<lastmod>` implemented
# - ❌ If you're displaying your sitemap to Googlebot, you want to [avoid using  `<priority>` and `<changefreq>`](https://https://developers.google.com/search/docs/advanced/sitemaps/build-sitemap) values as Google ignores them.

# %%
#@title 3️⃣ Get a clue about the site-tree of your Website
sitemap_url_df = adv.url_to_df(sitemap_df["loc"])
sitemap_url_df
# Out:
#                                                  url scheme         netloc  \
# 0                             https://seodepths.com/  https  seodepths.com
# 1  https://seodepths.com/python-for-seo/entity-an...  https  seodepths.com
# 2  https://seodepths.com/seo-news/how-nlp-nlu-can...  https  seodepths.com
# 3  https://seodepths.com/python-for-seo/define-se...  https  seodepths.com
# 4  https://seodepths.com/python-for-seo/how-to-ki...  https  seodepths.com
# 5  https://seodepths.com/python-for-seo/sitemap-a...  https  seodepths.com
# 6  https://seodepths.com/python-for-seo/detect-go...  https  seodepths.com
# 7  https://seodepths.com/seo-news/google-pros-con...  https  seodepths.com
# 8                             https://seodepths.com/  https  seodepths.com
# 9                       https://seodepths.com/about/  https  seodepths.com
#
#                                                 path  query  fragment  \
# 0                                                  /    NaN       NaN
# 1  /python-for-seo/entity-and-sentiment-analysis-...    NaN       NaN
# 2              /seo-news/how-nlp-nlu-can-affect-seo/    NaN       NaN
# 3  /python-for-seo/define-seo-search-intent-with-...    NaN       NaN
# 4  /python-for-seo/how-to-kick-off-entity-researc...    NaN       NaN
# 5              /python-for-seo/sitemap-audit-python/    NaN       NaN
# 6  /python-for-seo/detect-google-tag-rewriting-se...    NaN       NaN
# 7            /seo-news/google-pros-cons-annotations/    NaN       NaN
# 8                                                  /    NaN       NaN
# 9                                            /about/    NaN       NaN
#
#             dir_1                                       dir_2  \
# 0             NaN                                         NaN
# 1  python-for-seo        entity-and-sentiment-analysis-python
# 2        seo-news                  how-nlp-nlu-can-affect-seo
# 3  python-for-seo        define-seo-search-intent-with-python
# 4  python-for-seo  how-to-kick-off-entity-research-nlp-python
# 5  python-for-seo                        sitemap-audit-python
# 6  python-for-seo         detect-google-tag-rewriting-serpapi
# 7        seo-news                google-pros-cons-annotations
# 8             NaN                                         NaN
# 9           about                                         NaN
#
#                                      last_dir
# 0                                         NaN
# 1        entity-and-sentiment-analysis-python
# 2                  how-nlp-nlu-can-affect-seo
# 3        define-seo-search-intent-with-python
# 4  how-to-kick-off-entity-research-nlp-python
# 5                        sitemap-audit-python
# 6         detect-google-tag-rewriting-serpapi
# 7                google-pros-cons-annotations
# 8                                         NaN
# 9                                       about

# %%
#@title 4️⃣ Get a grip on HTTPS Usage on URLs in the Sitemap
sitemap_url_df["scheme"].value_counts().to_frame()
# Out:
#        scheme
# https      10

# %% [markdown]
# ## 🤖 ROBOTS.TXT

# %%
#@title 5️⃣ Have a look at the Robots.txt 
import requests
r = requests.get("https://www.seodepths.com/robots.txt")
r.status_code
# Out:
# 200

# %% [markdown]
# If the response status code is 200, it means there is a robots.txt file for the user-agent-based crawling control.

# %%
#@title 6️⃣ Bulk audit Robots.txt of the URLs in the sitemap
sitemap_df_robotstxt_check = adv.robotstxt_test("https://www.seodepths.com/robots.txt", urls=sitemap_df["loc"], user_agents=["*"])
sitemap_df_robotstxt_check["can_fetch"].value_counts()
# Out:
# True    10
# Name: can_fetch, dtype: int64

# %% [markdown]
# # 📓 SIDENOTES
#
# **user_agents=["*"]** = we have performed the audit for all of the user-agents
#
# **True** =  URLs are all crawlable.
#
# **False** = some URLs are being disallowed
#
# 👇
#
#
# ---
# If URLs are being disallowed, run the script below

# %%
#@title Identify disallowed URLs
pd.set_option("display.max_colwidth",255)
sitemap_df_robotstxt_check[sitemap_df_robotstxt_check["can_fetch"] == False]
# Out:
# Empty DataFrame
# Columns: [robotstxt_url, user_agent, url_path, can_fetch]
# Index: []

# %% [markdown]
# ## STATUS CODE CHECK

# %%
#@title Check URLs Status Code within the Sitemap
adv.crawl_headers(sitemap_df["loc"], output_file="sitemap_df_header.jl")
df_headers = pd.read_json("sitemap_df_header.jl", lines=True)
df_headers["status"].value_counts()
# Out:
# 200    27
# Name: status, dtype: int64

# %% [markdown]
# ❌ **If any, which URLs in the sitemaps return 404?**

# %%
df_headers[df_headers["status"] == 404]
# Out:
# Empty DataFrame
# Columns: [url, crawl_time, status, download_timeout, download_slot, download_latency, depth, protocol, body, resp_headers_content-length, resp_headers_server, resp_headers_date, resp_headers_content-type, resp_headers_strict-transport-security, resp_headers_vary, resp_headers_x-hacker, resp_headers_host-header, resp_headers_cache-control, resp_headers_x-nitro-cache, resp_headers_x-nitro-cache-from, resp_headers_x-nitro-rev, resp_headers_link, resp_headers_x-cache-ctime, resp_headers_content-encoding, resp_headers_x-ac, request_headers_accept, request_headers_accept-language, request_headers_user-agent, request_headers_accept-encoding, resp_headers_last-modified, resp_headers_x-nananana, resp_headers_x-pingback]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# ##⚠️ NOT COMPULSORY - Check Canonicalization from Response Headers
#
#
# ---
#
# From time to time, **using canonicalization hints on the response headers is beneficial for crawling and indexing**
#
# **If you want to include a canonicalization hint on the HTTP header, you need to guarantee that the URL canonical tag and the respsonse header canonical tag are the same**.
#
# The following steps will be:
# - Checking  whether the response header for canonical usage exists.
# - Comparing the response header canonical value to the HTML canonical value - if it exists.
# - Checking whether the canonical values are self-referential.

# %%
#@title Does a response header for canonical usage exists?
df_headers.columns
# the answer is "YES" if the output retrieves a 'resp_headers_link'
# Out:
# Index(['url', 'crawl_time', 'status', 'download_timeout', 'download_slot',
#        'download_latency', 'depth', 'protocol', 'body',
#        'resp_headers_content-length', 'resp_headers_server',
#        'resp_headers_date', 'resp_headers_content-type',
#        'resp_headers_strict-transport-security', 'resp_headers_vary',
#        'resp_headers_x-hacker', 'resp_headers_host-header',
#        'resp_headers_cache-control', 'resp_headers_x-nitro-cache',
#        'resp_headers_x-nitro-cache-from', 'resp_headers_x-nitro-rev',
#        'resp_headers_link', 'resp_headers_x-cache-ctime',
#        'resp_headers_content-encoding', 'resp_headers_x-ac',
#        'request_headers_accept', 'request_headers_accept-language',
#        'request_headers_user-agent', 'request_headers_accept-encoding',
#        'resp_headers_last-modified', 'resp_headers_x-nananana',
#        'resp_headers_x-pingback'],
#       dtype='object')

# %%
#@title Compare the response header canonical to the HTML canonical
df_headers["resp_headers_link"]
print("Checking any links within the Response Header")

df_headers["response_header_canonical"] = df_headers["resp_headers_link"].str.extract(r"([^<>][a-z:\/0-9-.]*)")
(df_headers["response_header_canonical"] == df_headers["url"]).value_counts()
# Out:
# Checking any links within the Response Header
# False    27
# dtype: int64

# %% [markdown]
# ## **True** = the response header canonical equals the URL canonical
#
# ## **False** = the response header canonical DOES NOT equal the URL canonical

# %%
#@title Define the Canonical Values from the Response Header
df_headers[(df_headers["response_header_canonical"] != df_headers["url"]) & (df_headers["status"] == 200)]
# Out:
#                                                                                  url  \
# 0                                                             https://seodepths.com/
# 1         https://seodepths.com/python-for-seo/entity-and-sentiment-analysis-python/
# 2                         https://seodepths.com/python-for-seo/sitemap-audit-python/
# 3         https://seodepths.com/python-for-seo/define-seo-search-intent-with-python/
# 4          https://seodepths.com/python-for-seo/detect-google-tag-rewriting-serpapi/
# 5   https://seodepths.com/python-for-seo/how-to-kick-off-entity-research-nlp-python/
# 6                       https://seodepths.com/seo-news/google-pros-cons-annotations/
# 7                         https://seodepths.com/seo-news/how-nlp-nlu-can-affect-seo/
# 8                                                       https://seodepths.com/about/
# 9                                                             https://seodepths.com/
# 10         https://seodepths.com/python-for-seo/detect-google-tag-rewriting-serpapi/
# 11        https://seodepths.com/python-for-seo/define-seo-search-intent-with-python/
# 12        https://seodepths.com/python-for-seo/entity-and-sentiment-analysis-python/
# 13  https://seodepths.com/python-for-seo/how-to-kick-off-entity-research-nlp-python/
# 14                        https://seodepths.com/python-for-seo/sitemap-audit-python/
# 15                        https://seodepths.com/seo-news/how-nlp-nlu-can-affect-seo/
# 16                      https://seodepths.com/seo-news/google-pros-cons-annotations/
# 17                                                      https://seodepths.com/about/
# 18                                                            https://seodepths.com/
# 19                        https://seodepths.com/python-for-seo/sitemap-audit-python/
# 20  https://seodepths.com/python-for-seo/how-to-kick-off-entity-research-nlp-python/
# 21         https://seodepths.com/python-for-seo/detect-google-tag-rewriting-serpapi/
# 22        https://seodepths.com/python-for-seo/entity-and-sentiment-analysis-python/
# 23        https://seodepths.com/python-for-seo/define-seo-search-intent-with-python/
# 24                        https://seodepths.com/seo-news/how-nlp-nlu-can-affect-seo/
# 25                      https://seodepths.com/seo-news/google-pros-cons-annotations/
# 26                                                      https://seodepths.com/about/
#
#             crawl_time  status  download_timeout  download_slot  \
# 0  2022-07-17 14:18:57     200               180  seodepths.com
# 1  2022-07-17 14:18:57     200               180  seodepths.com
# 2  2022-07-17 14:18:57     200               180  seodepths.com
# 3  2022-07-17 14:18:57     200               180  seodepths.com
# 4  2022-07-17 14:18:57     200               180  seodepths.com
# 5  2022-07-17 14:18:57     200               180  seodepths.com
# 6  2022-07-17 14:18:57     200               180  seodepths.com
# 7  2022-07-17 14:18:57     200               180  seodepths.com
# 8  2022-07-17 14:18:57     200               180  seodepths.com
# 9  2022-07-17 14:24:03     200               180  seodepths.com
# 10 2022-07-17 14:24:03     200               180  seodepths.com
# 11 2022-07-17 14:24:04     200               180  seodepths.com
# 12 2022-07-17 14:24:04     200               180  seodepths.com
# 13 2022-07-17 14:24:04     200               180  seodepths.com
# 14 2022-07-17 14:24:04     200               180  seodepths.com
# 15 2022-07-17 14:24:04     200               180  seodepths.com
# 16 2022-07-17 14:24:04     200               180  seodepths.com
# 17 2022-07-17 14:24:04     200               180  seodepths.com
# 18 2022-07-17 14:25:42     200               180  seodepths.com
# 19 2022-07-17 14:25:43     200               180  seodepths.com
# 20 2022-07-17 14:25:43     200               180  seodepths.com
# 21 2022-07-17 14:25:43     200               180  seodepths.com
# 22 2022-07-17 14:25:43     200               180  seodepths.com
# 23 2022-07-17 14:25:43     200               180  seodepths.com
# 24 2022-07-17 14:25:43     200               180  seodepths.com
# 25 2022-07-17 14:25:43     200               180  seodepths.com
# 26 2022-07-17 14:25:43     200               180  seodepths.com
#
#     download_latency  depth  protocol  body  resp_headers_content-length  ...  \
# 0           0.152629      0  HTTP/1.1   NaN                            0  ...
# 1           0.193086      0  HTTP/1.1   NaN                            0  ...
# 2           0.191443      0  HTTP/1.1   NaN                            0  ...
# 3           0.199115      0  HTTP/1.1   NaN                            0  ...
# 4           0.196270      0  HTTP/1.1   NaN                            0  ...
# 5           0.206657      0  HTTP/1.1   NaN                            0  ...
# 6           0.306869      0  HTTP/1.1   NaN                            0  ...
# 7           0.359001      0  HTTP/1.1   NaN                            0  ...
# 8           0.248889      0  HTTP/1.1   NaN                            0  ...
# 9           0.138918      0  HTTP/1.1   NaN                            0  ...
# 10          0.186064      0  HTTP/1.1   NaN                            0  ...
# 11          0.194310      0  HTTP/1.1   NaN                            0  ...
# 12          0.199594      0  HTTP/1.1   NaN                            0  ...
# 13          0.198297      0  HTTP/1.1   NaN                            0  ...
# 14          0.201500      0  HTTP/1.1   NaN                            0  ...
# 15          0.317477      0  HTTP/1.1   NaN                            0  ...
# 16          0.380974      0  HTTP/1.1   NaN                            0  ...
# 17          0.315422      0  HTTP/1.1   NaN                            0  ...
# 18          0.105770      0  HTTP/1.1   NaN                            0  ...
# 19          0.186304      0  HTTP/1.1   NaN                            0  ...
# 20          0.196801      0  HTTP/1.1   NaN                            0  ...
# 21          0.195133      0  HTTP/1.1   NaN                            0  ...
# 22          0.203720      0  HTTP/1.1   NaN                            0  ...
# 23          0.205187      0  HTTP/1.1   NaN                            0  ...
# 24          0.316851      0  HTTP/1.1   NaN                            0  ...
# 25          0.312581      0  HTTP/1.1   NaN                            0  ...
# 26          0.254992      0  HTTP/1.1   NaN                            0  ...
#
#    resp_headers_content-encoding  resp_headers_x-ac  \
# 0                           gzip  3.dca _atomic_dca
# 1                           gzip  3.dca _atomic_dca
# 2                           gzip  3.dca _atomic_dca
# 3                           gzip  3.dca _atomic_dca
# 4                           gzip  3.dca _atomic_dca
# 5                           gzip  3.dca _atomic_dca
# 6                           gzip  3.dca _atomic_dca
# 7                           gzip  3.dca _atomic_dca
# 8                           gzip  3.dca _atomic_dca
# 9                           gzip  3.dca _atomic_dca
# 10                          gzip  3.dca _atomic_dca
# 11                          gzip  3.dca _atomic_dca
# 12                          gzip  3.dca _atomic_dca
# 13                          gzip  3.dca _atomic_dca
# 14                          gzip  3.dca _atomic_dca
# 15                          gzip  3.dca _atomic_dca
# 16                          gzip  3.dca _atomic_dca
# 17                          gzip  3.dca _atomic_dca
# 18                          gzip  3.dca _atomic_dca
# 19                          gzip  3.dca _atomic_dca
# 20                          gzip  3.dca _atomic_dca
# 21                          gzip  3.dca _atomic_dca
# 22                          gzip  3.dca _atomic_dca
# 23                          gzip  3.dca _atomic_dca
# 24                          gzip  3.dca _atomic_dca
# 25                          gzip  3.dca _atomic_dca
# 26                          gzip  3.dca _atomic_dca
#
#                                              request_headers_accept  \
# 0   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 1   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 2   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 3   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 4   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 5   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 6   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 7   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 8   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 9   text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 10  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 11  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 12  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 13  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 14  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 15  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 16  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 17  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 18  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 19  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 20  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 21  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 22  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 23  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 24  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 25  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
# 26  text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8
#
#    request_headers_accept-language request_headers_user-agent  \
# 0                               en          advertools/0.13.1
# 1                               en          advertools/0.13.1
# 2                               en          advertools/0.13.1
# 3                               en          advertools/0.13.1
# 4                               en          advertools/0.13.1
# 5                               en          advertools/0.13.1
# 6                               en          advertools/0.13.1
# 7                               en          advertools/0.13.1
# 8                               en          advertools/0.13.1
# 9                               en          advertools/0.13.1
# 10                              en          advertools/0.13.1
# 11                              en          advertools/0.13.1
# 12                              en          advertools/0.13.1
# 13                              en          advertools/0.13.1
# 14                              en          advertools/0.13.1
# 15                              en          advertools/0.13.1
# 16                              en          advertools/0.13.1
# 17                              en          advertools/0.13.1
# 18                              en          advertools/0.13.1
# 19                              en          advertools/0.13.1
# 20                              en          advertools/0.13.1
# 21                              en          advertools/0.13.1
# 22                              en          advertools/0.13.1
# 23                              en          advertools/0.13.1
# 24                              en          advertools/0.13.1
# 25                              en          advertools/0.13.1
# 26                              en          advertools/0.13.1
#
#    request_headers_accept-encoding     resp_headers_last-modified  \
# 0                    gzip, deflate                            NaN
# 1                    gzip, deflate  Sun, 17 Jul 2022 14:18:57 GMT
# 2                    gzip, deflate                            NaN
# 3                    gzip, deflate  Sun, 17 Jul 2022 14:18:57 GMT
# 4                    gzip, deflate  Sun, 17 Jul 2022 14:18:57 GMT
# 5                    gzip, deflate  Sun, 17 Jul 2022 14:18:57 GMT
# 6                    gzip, deflate                            NaN
# 7                    gzip, deflate                            NaN
# 8                    gzip, deflate                            NaN
# 9                    gzip, deflate  Sun, 17 Jul 2022 14:24:03 GMT
# 10                   gzip, deflate                            NaN
# 11                   gzip, deflate                            NaN
# 12                   gzip, deflate                            NaN
# 13                   gzip, deflate                            NaN
# 14                   gzip, deflate  Sun, 17 Jul 2022 14:24:03 GMT
# 15                   gzip, deflate                            NaN
# 16                   gzip, deflate                            NaN
# 17                   gzip, deflate                            NaN
# 18                   gzip, deflate  Sun, 17 Jul 2022 14:24:03 GMT
# 19                   gzip, deflate  Sun, 17 Jul 2022 14:24:03 GMT
# 20                   gzip, deflate  Sun, 17 Jul 2022 14:25:42 GMT
# 21                   gzip, deflate  Sun, 17 Jul 2022 14:25:42 GMT
# 22                   gzip, deflate  Sun, 17 Jul 2022 14:25:42 GMT
# 23                   gzip, deflate  Sun, 17 Jul 2022 14:25:42 GMT
# 24                   gzip, deflate                            NaN
# 25                   gzip, deflate                            NaN
# 26                   gzip, deflate                            NaN
#
#    resp_headers_x-nananana           resp_headers_x-pingback  \
# 0                      NaN                               NaN
# 1             Batcache-Set                               NaN
# 2                      NaN                               NaN
# 3             Batcache-Set                               NaN
# 4             Batcache-Set  https://seodepths.com/xmlrpc.php
# 5             Batcache-Set  https://seodepths.com/xmlrpc.php
# 6                      NaN  https://seodepths.com/xmlrpc.php
# 7                      NaN                               NaN
# 8                      NaN                               NaN
# 9             Batcache-Set                               NaN
# 10                     NaN  https://seodepths.com/xmlrpc.php
# 11                     NaN                               NaN
# 12                     NaN                               NaN
# 13                     NaN  https://seodepths.com/xmlrpc.php
# 14            Batcache-Set                               NaN
# 15                     NaN                               NaN
# 16                     NaN  https://seodepths.com/xmlrpc.php
# 17                     NaN                               NaN
# 18            Batcache-Hit                               NaN
# 19            Batcache-Hit                               NaN
# 20            Batcache-Set  https://seodepths.com/xmlrpc.php
# 21            Batcache-Set  https://seodepths.com/xmlrpc.php
# 22            Batcache-Set                               NaN
# 23            Batcache-Set                               NaN
# 24                     NaN                               NaN
# 25                     NaN  https://seodepths.com/xmlrpc.php
# 26                     NaN                               NaN
#
#          response_header_canonical
# 0   https://cdn-gbphn.nitrocdn.com
# 1   https://cdn-gbphn.nitrocdn.com
# 2   https://cdn-gbphn.nitrocdn.com
# 3   https://cdn-gbphn.nitrocdn.com
# 4   https://cdn-gbphn.nitrocdn.com
# 5   https://cdn-gbphn.nitrocdn.com
# 6   https://seodepths.com/wp-json/
# 7   https://seodepths.com/wp-json/
# 8   https://seodepths.com/wp-json/
# 9   https://cdn-gbphn.nitrocdn.com
# 10  https://cdn-gbphn.nitrocdn.com
# 11  https://cdn-gbphn.nitrocdn.com
# 12  https://cdn-gbphn.nitrocdn.com
# 13  https://cdn-gbphn.nitrocdn.com
# 14  https://cdn-gbphn.nitrocdn.com
# 15  https://seodepths.com/wp-json/
# 16  https://seodepths.com/wp-json/
# 17  https://seodepths.com/wp-json/
# 18  https://cdn-gbphn.nitrocdn.com
# 19  https://cdn-gbphn.nitrocdn.com
# 20  https://cdn-gbphn.nitrocdn.com
# 21  https://cdn-gbphn.nitrocdn.com
# 22  https://cdn-gbphn.nitrocdn.com
# 23  https://cdn-gbphn.nitrocdn.com
# 24  https://seodepths.com/wp-json/
# 25  https://seodepths.com/wp-json/
# 26  https://seodepths.com/wp-json/
#
# [27 rows x 33 columns]

# %%
#@title Check whether the canonical values are self-referential
df_headers["response_header_canonical"] = df_headers["resp_headers_link"].str.extract(r"([^<>][a-z:\/0-9-.]*)")
(df_headers["response_header_canonical"] == df_headers["url"]).value_counts()
# Out:
# False    27
# dtype: int64

# %% [markdown]
# ## Check for X-Robots Tag in the Sitemap
#
#
# ---
# You might want to check whether an X-robots tag was appended within the response header as a result of a temporary amendment to the Robots.txt directives.

# %%
#@title Does an X-Robots Tag exists within the URLs on the Sitemap?
def robots_tag_checker(dataframe:pd.DataFrame):
     for i in df_headers:
          if i.__contains__("robots"):
               return i
          else:
               return "There is no robots tag"
robots_tag_checker(df_headers)
# Out:
# 'There is no robots tag'

# %% [markdown]
# ## ❌ If there were an X-Robot Tag, you should use the code below
#
#
#
#
#
# ---
#
# **We can check whether there is a “noindex” directive from the response headers**
#
# In the Google Search Console Coverage Report, those appear as “Submitted marked as noindex”.
#
# Contradicting indexing and canonicalization hints and signals might make a search engine ignore all of the signals while making the search algorithms trust less to the user-declared signals.

# %%
df_headers["response_header_x_robots_tag"].value_counts()
df_headers[df_headers["response_header_x_robots_tag"] == "noindex"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'response_header_x_robots_tag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e6cdcd5b01d9> in <module>()
# ----> 1 df_headers["response_header_x_robots_tag"].value_counts()
#       2 df_headers[df_headers["response_header_x_robots_tag"] == "noindex"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'response_header_x_robots_tag'

# %% [markdown]
# ##Audit Meta Tag Robots
#
#
#
# ---
# Even if a web page is not disallowed from robots.txt, it can still be disallowed from the HTML Meta Tags.
#
# Thus, checking the HTML Meta Tags for better indexation and crawling is necessary.
#
# Using the “custom selectors” is necessary to perform the HTML Meta Tag audit for the sitemap URLs.
#
#
# ---
#
# 📓 If "False" is the returned value, there are no URLs with **noindex|nofollow** attribute within the Robots command.

# %%
sitemap = adv.sitemap_to_df("https://seodepths.com/sitemap_index.xml")

adv.crawl(url_list=sitemap["loc"][:1000], output_file="meta_command_audit.jl",

follow_links=False,

xpath_selectors= {"meta_command": "//meta[@name='robots']/@content"}, # to extract all the robots commands from the URLs from the sitemap.

custom_settings={"CLOSESPIDER_PAGECOUNT":1000}) # we have set the crawling to 1000 URLs from hte sitemap

df_meta_check = pd.read_json("meta_command_audit.jl", lines=True)

df_meta_check["meta_command"].str.contains("nofollow|noindex", regex=True).value_counts()
# Out:
# 2022-07-17 15:51:34,361 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://seodepths.com/page-sitemap.xml
# 2022-07-17 15:51:34,373 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://seodepths.com/post-sitemap.xml
# False    18
# Name: meta_command, dtype: int64

# %% [markdown]
# ##⚠️ WARNING - If your GSC informs you about **indexing issues** stemming from a URL apparently displaying a **Index,Follow**, you should inspect the `<body>` section of the URL to assess whether a **noindex,follow** is in place

# %%
#@title View the Meta Tag Robots applied on the Sitemap URLs
df_meta_check[df_meta_check["meta_command"].str.contains("nofollow|noindex", regex=True) == False][["url", "meta_command"]]
# Out:
#                                                                                  url  \
# 0                                                             https://seodepths.com/
# 1         https://seodepths.com/python-for-seo/define-seo-search-intent-with-python/
# 2   https://seodepths.com/python-for-seo/how-to-kick-off-entity-research-nlp-python/
# 3          https://seodepths.com/python-for-seo/detect-google-tag-rewriting-serpapi/
# 4                         https://seodepths.com/python-for-seo/sitemap-audit-python/
# 5         https://seodepths.com/python-for-seo/entity-and-sentiment-analysis-python/
# 6                                                       https://seodepths.com/about/
# 7                         https://seodepths.com/seo-news/how-nlp-nlu-can-affect-seo/
# 8                       https://seodepths.com/seo-news/google-pros-cons-annotations/
# 9                                                             https://seodepths.com/
# 10                        https://seodepths.com/python-for-seo/sitemap-audit-python/
# 11        https://seodepths.com/python-for-seo/entity-and-sentiment-analysis-python/
# 12  https://seodepths.com/python-for-seo/how-to-kick-off-entity-research-nlp-python/
# 13        https://seodepths.com/python-for-seo/define-seo-search-intent-with-python/
# 14         https://seodepths.com/python-for-seo/detect-google-tag-rewriting-serpapi/
# 15                        https://seodepths.com/seo-news/how-nlp-nlu-can-affect-seo/
# 16                                                      https://seodepths.com/about/
# 17                      https://seodepths.com/seo-news/google-pros-cons-annotations/
#
#                                                                     meta_command
# 0                                                                  index, follow
# 1                         index, follow, max-snippet:-1, max-image-preview:large
# 2                         index, follow, max-snippet:-1, max-image-preview:large
# 3   follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large
# 4                         index, follow, max-image-preview:large, max-snippet:-1
# 5                         index, follow, max-snippet:-1, max-image-preview:large
# 6   follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large
# 7                         index, follow, max-snippet:-1, max-image-preview:large
# 8   follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large
# 9                                                                  index, follow
# 10                        index, follow, max-image-preview:large, max-snippet:-1
# 11                        index, follow, max-snippet:-1, max-image-preview:large
# 12                        index, follow, max-snippet:-1, max-image-preview:large
# 13                        index, follow, max-snippet:-1, max-image-preview:large
# 14  follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large
# 15                        index, follow, max-snippet:-1, max-image-preview:large
# 16  follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large
# 17  follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large

# %% [markdown]
# #Check the duplicate URLs within the Sitemap URLs

# %%
#@title Look for Duplicate URLs Within Sitemap Submissions
sitemap_df["loc"].duplicated().value_counts()
# Out:
# False    9
# True     1
# Name: loc, dtype: int64

# %% [markdown]
# 📓 **False = no duplicated URLs are uploaded in the sitemap**
#
# ❌ **True** = Duplicated URLs are caught in the Sitemap
#
# 👇
#
# ---
# Should you have Duplicated URLs uploaded in your Sitemap, run the script below

# %%
#@title ❌ How many duplicated URLs in the Sitemap?
pd.pivot_table(sitemap_df[sitemap_df["loc"].duplicated()==True], index="sitemap", values="loc", aggfunc="count").sort_values(by="loc", ascending=False)
# Out:
#                                         loc
# sitemap
# https://seodepths.com/page-sitemap.xml    1

# %%
#@title 💡Which URLs are caught as Duplicated in the Sitemap?
sitemap_df[sitemap_df["loc"].duplicated() == True]
# Out:
#                       loc lastmod image image_loc  \
# 8  https://seodepths.com/     NaN   NaN       NaN
#
#                                   sitemap  sitemap_size_mb  \
# 8  https://seodepths.com/page-sitemap.xml         0.000737
#
#                       download_date
# 8  2022-07-17 13:43:55.158998+00:00
